# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a380_data = np.genfromtxt("a380_memory.csv", delimiter=",")
x35_data = np.genfromtxt("x35_memory.csv", delimiter=",")
# rays=np.arange(10,110,10)
# print(rays)
# data[:,0] /= 1E9
# corner = data[0:6]
# x35 = data[6:12]
# hawker = data[12:18]
# a380 = data[18:22]
# rays_a380=np.arange(10,60,10)
fig, ax = plt.subplots()
# ax.plot(corner[:,0], corner[:,1], label="corner reflector")
# ax.plot(x35[:,0], x35[:,1], label="X-35")
# ax.plot(hawker[:,0], hawker[:,1], label="Hawker 900")
ax.plot(a380_data[:,0]**2 / 1E7, a380_data[:,1], label="A380")
ax.plot(x35_data[:,0]**2 / 1E7, x35_data[:,1], label="X-35")
# ax.set_title("Time for 90 angles",fontsize=15)
ax.legend()
ax.set_xlabel("Number of launched rays (10E7)")
ax.set_ylabel("GPU memory usage (MB)")
# ax.show()
fig.savefig('memory versus number of rays.png', transparent=True)
