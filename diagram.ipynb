# %%
import subprocess
import numpy as np
import matplotlib.pyplot as plt

# %%
model = "corner_reflector"
rcs_file = "output/" + model + '_rcs.csv'
exePath = "C://development//optix//OptixRCS//build//bin//Release//TrianglesRcs.exe"

# %%
open(rcs_file, "w").close()

phi = "[0:90:1]"
theta = "[60:60:1]"
freq = "3E9"
subprocess.run([exePath, str(freq), str(phi), str(theta), model])
print(model, phi, theta, freq)
# Out:
# corner_reflector [0:90:1] [60:60:1] 3E9

# %%
csv = np.genfromtxt (rcs_file, delimiter=",")

# Extract phi and rcs columns from the DataFrame
freq_values = csv[:,0]
phi_values = csv[:,1]
theta_values = csv[:,2]
rcs_values = csv[:,3]

# %%
# Create the plot
plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(phi_values, rcs_values)
plt.xlabel('Phi')  # X-axis label
plt.ylabel('RCS')  # Y-axis label
plt.title('RCS vs Phi')  # Plot title
plt.show()  # Display the plot

# %%
# Create the plot
plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(theta_values, rcs_values)
plt.xlabel('Theta')  # X-axis label
plt.ylabel('RCS')  # Y-axis label
plt.title('RCS vs Theta')  # Plot title
plt.show()  # Display the plot

# %%
# Create the plot
plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(freq_values, rcs_values)
plt.xlabel('freq')  # X-axis label
plt.ylabel('RCS')  # Y-axis label
plt.title('RCS vs freq')  # Plot title
plt.show()  # Display the plot
